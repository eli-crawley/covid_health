# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns

# %%
# Create a reference the CSV file desired
adverse_path = "Resources/VAERSDATA1 (3).csv"

# Read the CSV into a Pandas DataFrame
adverse = pd.read_csv(adverse_path, low_memory=False)

# Print the first five rows of data to the screen
adverse.head()
# Out:
#    VAERS_ID   RECVDATE STATE  AGE_YRS SEX DIED DATEDIED RECOVD   VAX_DATE  \
# 0   1021156  2/10/2021    IL       32   F  NaN      NaN      N  1/27/2021
# 1   1029567  2/14/2021    NH       61   M  NaN      NaN      U  2/14/2021
# 2   1061353  2/28/2021    WA       74   M  NaN      NaN      N  2/24/2021
# 3   1066793   3/2/2021    AZ       81   M  NaN      NaN      N  2/12/2021
# 4   1219181  4/16/2021    TX       15   M  NaN      NaN      Y  4/15/2021
#
#   ONSET_DATE  NUMDAYS V_ADMINBY         VAX_MANU HISTORY             ALLERGIES
# 0   2/4/2021      8.0       SEN          MODERNA     NaN                   Nka
# 1  2/14/2021      0.0       PUB          MODERNA     NaN                   NaN
# 2  2/24/2021      0.0       PUB  PFIZER\BIONTECH     NaN  sulfa based products
# 3  2/26/2021     14.0       PUB  PFIZER\BIONTECH     NaN                   NaN
# 4  4/15/2021      0.0       PVT  PFIZER\BIONTECH     NaN                   NaN

# %%
# Extract records for male and female
died_records = adverse[adverse["DIED"] == "Y"]
# Out:
# Number of died records: 16906
#        VAERS_ID    RECVDATE STATE  AGE_YRS SEX DIED   DATEDIED RECOVD  \
# 32      1261766   4/27/2021    FL        1   M    Y  4/10/2021      N
# 152     2639957    6/1/2023    WI        1   M    Y  4/29/2023      N
# 1097    2506670  11/12/2022    MA        1   M    Y  10/7/2022      N
# 10888   2152560    3/2/2022    WA        7   M    Y  2/16/2022      N
# 13119   2109625   2/13/2022    MS        8   M    Y  2/11/2022      N
#
#         VAX_DATE ONSET_DATE  NUMDAYS V_ADMINBY         VAX_MANU  \
# 32      4/8/2021  4/10/2021      2.0       UNK          MODERNA
# 152     4/7/2023  4/29/2023     22.0       PVT          MODERNA
# 1097   8/10/2022  10/7/2022     58.0       PVT          MODERNA
# 10888   2/3/2022  2/16/2022     13.0       PVT  PFIZER\BIONTECH
# 13119   2/3/2022  2/11/2022      8.0       PVT  PFIZER\BIONTECH
#
#                                                 HISTORY ALLERGIES
# 32                                                  NaN       NaN
# 152                                                 NaN       NaN
# 1097                                                N/a       N/a
# 10888  None.   Primary care visit in 2021 showed BMI 62       NaN
# 13119                                               NaN       NaN

# %%
# creating bins
bins = list(range(0, 111, 10))
labels=[f"{i}-{i+9}" for i in range(0,110,10)]
died_records.loc[:,"Age_Group"]=pd.cut(died_records["AGE_YRS"],bins=bins,labels=labels,right=False)
died_records.head()
# Out:
# C:\Users\rmwc_\AppData\Local\Temp\ipykernel_53800\3855263692.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0-9', '0-9', '0-9', '0-9', '0-9', ..., '70-79', '70-79', '60-69', '60-69', '70-79']
# Length: 16906
# Categories (11, object): ['0-9' < '10-19' < '20-29' < '30-39' ... '70-79' < '80-89' < '90-99' < '100-109']' has dtype incompatible with category, please explicitly cast to a compatible dtype first.
#   died_records.loc[:,"Age_Group"]=pd.cut(died_records["AGE_YRS"],bins=bins,labels=labels,right=False)
#       VAERS_ID    RECVDATE STATE  AGE_YRS SEX DIED    DATEDIED RECOVD  \
# 32     1261766   4/27/2021    FL        1   M    Y   4/10/2021      N
# 152    2639957    6/1/2023    WI        1   M    Y   4/29/2023      N
# 1097   2506670  11/12/2022    MA        1   M    Y   10/7/2022      N
# 1664   2536846  12/19/2022    NH        2   F    Y  12/16/2022      N
# 4908   1890705  11/22/2021    IA        5   F    Y  11/22/2021      N
#
#         VAX_DATE  ONSET_DATE  NUMDAYS V_ADMINBY         VAX_MANU  \
# 32      4/8/2021   4/10/2021      2.0       UNK          MODERNA
# 152     4/7/2023   4/29/2023     22.0       PVT          MODERNA
# 1097   8/10/2022   10/7/2022     58.0       PVT          MODERNA
# 1664  12/15/2022  12/16/2022      1.0       PVT          MODERNA
# 4908  11/18/2021  11/22/2021      4.0       PVT  PFIZER\BIONTECH
#
#                                                 HISTORY   ALLERGIES Age_Group
# 32                                                  NaN         NaN       0-9
# 152                                                 NaN         NaN       0-9
# 1097                                                N/a         N/a       0-9
# 1664                                            Unknown     Unknown       0-9
# 4908  PMH of twin to twin transfusion born at erm, n...  none known       0-9

# %%
# Optional: Display count of deaths per age group
age_group_counts = died_records["Age_Group"].value_counts().sort_index()
print(age_group_counts)

# Optional: Plot the age distribution of deaths
plt.figure(figsize=(10, 5))
sns.barplot(x=age_group_counts.index, y=age_group_counts.values, palette="viridis")
plt.xlabel("Age Group")
plt.ylabel("Number of Deaths")
plt.title("Death Count by Age Group")
plt.xticks(rotation=45)
plt.show()
# Out:
# Age_Group
# 0-9          14
# 10-19        82
# 20-29       170
# 30-39       301
# 40-49       552
# 50-59      1324
# 60-69      3142
# 70-79      4803
# 80-89      4470
# 90-99      1935
# 100-109     113
# Name: count, dtype: int64
# C:\Users\rmwc_\AppData\Local\Temp\ipykernel_53800\3591695100.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_group_counts.index, y=age_group_counts.values, palette="viridis")
